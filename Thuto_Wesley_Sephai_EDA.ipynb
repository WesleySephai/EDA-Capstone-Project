# %% [markdown]
# # Wesley Thuto Sephai
# ## EDA-Questions Assignment

# %% [markdown]
# ## Capstone project for Basic Data Science
# In this project, you would explore the Data preprocessing techniques learned. You will use, pandas, plots and the different data preprocessing techniques to explore and analyse the data. This project is on Exploratory Data Analysis

# %% [markdown]
# Step1: Import the necessary libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
#List the set of available datasets in seaborn
print(len(sns.get_dataset_names()))
print(sns.get_dataset_names())
# Out:
# 22
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %% [markdown]
# Dataset 1: exercise

# %%
#1.Write the syntax for choosing the specific dataset
df = sns.load_dataset("penguins")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# 1.OR OR OR
# Read the file (penguis.csv file) shared on the portal by me by placing it proper folder
df = pd.read_csv("penguins.csv")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
#2.Display the top 5 records of penguin dataset
#3.Display the dimensionality of the dataset

# %%
df.head(5)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.shape
# Out:
# (344, 7)

# %%
#4.Display the datatypes of the attributes

# %%
df.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
#5.Describe the dataset extensively

# %%
df.info()
df.describe()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      344     344      342.000000     342.000000         342.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       152     168             NaN            NaN                NaN
# ...

# %%
#6.Display the number of null values in the dataset and the total count of it

# %%
null_counts = df.isnull().sum()
print("Number of null values in each column:")
print(null_counts)

total_nulls = df.isnull().sum().sum()
print(f"Total number of null values in the dataset: {total_nulls}")
# Out:
# Number of null values in each column:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64
# Total number of null values in the dataset: 19

# %%
#7.Identify the columns having null values and remove them. Assume cleaned data is named as @penguins_cleaned

# %%
columns_with_nulls = df.columns[df.isnull().any()]
print("Columns with null values:")
print(columns_with_nulls)

penguins_cleaned = df.drop(columns=columns_with_nulls)


print("Columns after removing those with null values:")
print(penguins_cleaned.columns)
# Out:
# Columns with null values:
# Index(['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g',
#        'sex'],
#       dtype='object')
# Columns after removing those with null values:
# Index(['species', 'island'], dtype='object')

# %%
# 8.check the size of dataset after cleaning and compare with the size before cleaning

# %%
size_before = df.shape
print(f"Size of the dataset before cleaning: {size_before}")

columns_with_nulls = df.columns[df.isnull().any()]

penguins_cleaned = df.drop(columns=columns_with_nulls)

size_after = penguins_cleaned.shape
print(f"Size of the dataset after cleaning: {size_after}")

print(f"\nNumber of columns removed: {size_before[1] - size_after[1]}")
print(f"Number of rows (unchanged): {size_before[0]}")
# Out:
# Size of the dataset before cleaning: (344, 7)
# Size of the dataset after cleaning: (344, 2)
#
# Number of columns removed: 5
# Number of rows (unchanged): 344

# %%
#9.Find out the count of male and female penguins

# %%
print(df.head())        # Display the first few rows
print(df.columns)       # Display column names

sex_counts = df['sex'].value_counts()

print("Count of male and female penguins:")
print(sex_counts)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')
# Count of male and female penguins:
# sex
# MALE      168
# FEMALE    165
# Name: count, dtype: int64

# %%
#10.Find out the count of species

# %%
species_counts = df['species'].value_counts()

print("Count of each species:")
print(species_counts)
# Out:
# Count of each species:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
#11. Use a countplot graph to display the number of male and female penguins
#Give the plot a title "Count of male and female penguins"
#Give a xlabel and ylabel

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='sex', data=df)

plt.title('Count of Male and Female Penguins')
plt.xlabel('Sex')
plt.ylabel('Count')

plt.show()

# %%
#12. For all the penguins display the bill_length_mm and bill_depth_mm using pairplot

# %%
sns.pairplot(df[['bill_length_mm', 'bill_depth_mm']])


plt.suptitle('Pairplot of Bill Length and Bill Depth', y=1.02)
plt.show()

# %%
#13.Create a visualization to display the flipper_length_mm and body_mass_g for the penguin dataset.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='flipper_length_mm', y='body_mass_g', data=df)
plt.title('Scatter Plot of Flipper Length vs Body Mass')
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Body Mass (g)')
plt.show()


plt.figure(figsize=(8, 6))
sns.regplot(x='flipper_length_mm', y='body_mass_g', data=df)
plt.title('Regression Plot of Flipper Length vs Body Mass')
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Body Mass (g)')
plt.show()

# %%
#14. Create a histogram with the flipper_length_mm and bins = 10

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['flipper_length_mm'], bins=10, edgecolor='black')

plt.title('Histogram of Flipper Length')
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Frequency')

plt.show()

# %%
#15. Create a joint point with body_length_mm, body_depth_mm for penguins_cleaned dataset

# %%
df = pd.read_csv('penguins.csv')


df_cleaned = df.dropna()

df_cleaned = df_cleaned.drop_duplicates()

cleaned_file_path = 'penguins_cleaned.csv'
df_cleaned.to_csv(cleaned_file_path, index=False)

print(f"Cleaned dataset saved to {cleaned_file_path}")
# Out:
# Cleaned dataset saved to penguins_cleaned.csv

# %%
pd.read_csv('penguins_cleaned.csv')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
penguins_cleaned = pd.read_csv('penguins_cleaned.csv')

print(penguins_cleaned.columns)
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
print(penguins_cleaned.dtypes)

#penguins_cleaned['bill_length_mm'] = pd.to_numeric(penguins_cleaned['body_length_mm'], errors='coerce')
#penguins_cleaned['bill_depth_mm'] = pd.to_numeric(penguins_cleaned['body_depth_mm'], errors='coerce')
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
penguins_cleaned.rename(columns={
    'bill_length_mm': 'body_length_mm',
    'bill_depth_mm': 'body_depth_mm'
}, inplace=True)

penguins_cleaned.to_csv('updated_penguins_cleaned.csv', index=False)

print(penguins_cleaned.columns)
# Out:
# Index(['species', 'island', 'body_length_mm', 'body_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.jointplot(x='body_length_mm', y='body_depth_mm', data=penguins_cleaned, kind='scatter')
# set body_length_mm = bill_lenth
plt.suptitle('Joint Plot of Body Length vs Body Depth', y=1.02)
# Out:
# Text(0.5, 1.02, 'Joint Plot of Body Length vs Body Depth')

# %%
#16. Use a pairwise plot to display all the numerical values of the dataset penguins_cleaned

# %%
sns.pairplot(penguins_cleaned)

plt.suptitle('Pairwise Plot of Numerical Variables', y=1.02)

plt.show()

# %%
#17.Check if there exists any outliers based on the boxplot based on numerical values  of penguins_cleaned dataset

# %%
plt.figure(figsize=(12, 8))

# Create boxplots for all numerical columns
sns.boxplot(data=penguins_cleaned)

# Set plot title
plt.title('Boxplot of Numerical Variables')

# Display the plot
plt.show()

# %%
#18. Create a violin plot to display the body_mass_g of different species based on sex

# %%
plt.figure(figsize=(12, 8))

sns.violinplot(x='species', y='body_mass_g', hue='sex', data=penguins_cleaned, split=True)

plt.title('Distribution of Body Mass by Species and Sex')
plt.xlabel('Species')
plt.ylabel('Body Mass (g)')

plt.show()
